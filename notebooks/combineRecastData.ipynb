# %%
import pandas as pd
import os,glob

# %%
files = [f for f in glob.glob('../DMSimp_vector_0j_match/Events/run*/vector*cms*.pcl')]

# %%
allData = pd.read_pickle(files[0])
for f in files[1:]:
    recastData = pd.read_pickle(f)
    allData = pd.concat((allData,recastData),ignore_index=True)

    
allColumns = allData.columns.tolist()
orderColumns = ['Coupling','Mode','$m_{med}$','$m_{DM}$','Data-takingperiod'] 
orderColumns += [c for c in allColumns if not c in orderColumns]
allData = allData[orderColumns]
allData.sort_values(['Coupling','Mode','$m_{med}$','$m_{DM}$','Data-takingperiod'],inplace=True,
              ascending=[False,False,True,True,False],ignore_index=True)

# %%
allData
# Out:
#     Coupling        Mode  $m_{med}$  $m_{DM}$  Data-takingperiod  \
# 0     Vector  DM+QCDjets      100.0       1.0               2018
# 1     Vector  DM+QCDjets      100.0       1.0               2017
# 2     Vector  DM+QCDjets      100.0       1.0               2016
# 3     Vector  DM+QCDjets      100.0      30.0               2018
# 4     Vector  DM+QCDjets      100.0      30.0               2017
# ..       ...         ...        ...       ...                ...
# 199   Vector  DM+QCDjets     2500.0    1000.0               2017
# 200   Vector  DM+QCDjets     2500.0    1000.0               2016
# 201   Vector  DM+QCDjets     2500.0    1500.0               2018
# 202   Vector  DM+QCDjets     2500.0    1500.0               2017
# 203   Vector  DM+QCDjets     2500.0    1500.0               2016
#
#      Luminosity (1/fb)  bin_250.0_280.0  bin_250.0_280.0_ErrorPlus  \
# 0                 59.7    238762.168809               24028.355718
# 1                 41.5    253859.000376               22748.623265
# 2                 36.0    197986.400887               22261.269157
# 3                 59.7    250583.359582               24117.670893
# 4                 41.5    250551.420521               25475.909610
# ..                 ...              ...                        ...
# 199               41.5        40.347482                   3.541771
# 200               36.0        41.335824                   3.557078
# 201               59.7         0.199713                   0.018370
# 202               41.5         0.208876                   0.018452
# 203               36.0         0.186090                   0.018101
#
#      bin_250.0_280.0_ErrorMinus  bin_280.0_310.0  ...  Electronveto  Muonveto  \
# 0                  24028.355718    160448.946961  ...      0.138844  0.138844
# 1                  22748.623265    146339.431170  ...      0.139992  0.139992
# 2                  22261.269157    114053.753339  ...      0.128274  0.128274
# 3                  24117.670893    152289.397730  ...      0.143808  0.143808
# 4                  25475.909610    130135.313700  ...      0.136999  0.136999
# ..                          ...              ...  ...           ...       ...
# 199                    3.541771        27.908477  ...      0.446661  0.446531
# 200                    3.557078        28.490838  ...      0.446704  0.446665
# 201                    0.018370         0.129067  ...      0.407918  0.407875
# 202                    0.018452         0.136316  ...      0.416359  0.416429
# 203                    0.018101         0.106599  ...      0.403546  0.403546
#
#       Tauveto  Bjetveto  Photonveto  $\Delta \phi (jet,p_{T}^{miss})>0.5$ rad  \
# 0    0.136807  0.119814    0.118610                                  0.117755
# 1    0.135720  0.119814    0.118301                                  0.116986
# 2    0.126170  0.110334    0.109884                                  0.109242
# 3    0.141749  0.122219    0.121594                                  0.119204
# 4    0.133157  0.119754    0.118740                                  0.118004
# ..        ...       ...         ...                                       ...
# 199  0.436441  0.378299    0.364911                                  0.362978
# 200  0.439040  0.392868    0.377567                                  0.376673
# 201  0.396143  0.347511    0.336436                                  0.335851
# 202  0.404054  0.357878    0.344464                                  0.343666
# 203  0.392037  0.336118    0.324444                                  0.323488
#
#      LeadingAK4jet$p_{T}>100$GeV  LeadingAK4jet$\eta<2.4$  \
# 0                       0.114994                 0.114994
# 1                       0.114362                 0.114362
# 2                       0.107832                 0.107832
# 3                       0.116900                 0.116900
# 4                       0.115531                 0.115531
# ..                           ...                      ...
# 199                     0.359837                 0.359837
# 200                     0.372893                 0.372893
# 201                     0.334999                 0.334999
# 202                     0.339622                 0.339622
# 203                     0.320693                 0.320693
#
#      HCALmitigation(jets)  HCALmitigation($\phi^{miss}$)
# 0                0.110506                       0.094437
# 1                0.114362                       0.114362
# 2                0.107832                       0.107832
# 3                0.112396                       0.094379
# 4                0.115531                       0.115531
# ..                    ...                            ...
# 199              0.359837                       0.359837
# 200              0.372893                       0.372893
# 201              0.324445                       0.282565
# 202              0.339622                       0.339622
# 203              0.320693                       0.320693
#
# [204 rows x 91 columns]

# %%
allData.to_pickle('../scanResults_vector.pcl')
