# %%
import pandas as pd
import os,glob

# %%
files = [f for f in glob.glob('../DMSimp_axial_0j_match/Events/run*/axial*cms*.pcl')]

# %%
allData = pd.read_pickle(files[0])
for f in files[1:]:
    recastData = pd.read_pickle(f)
    allData = pd.concat((allData,recastData),ignore_index=True)

    
allColumns = allData.columns.tolist()
orderColumns = ['Coupling','Mode','$m_{med}$','$m_{DM}$','Data-takingperiod'] 
orderColumns += [c for c in allColumns if not c in orderColumns]
allData = allData[orderColumns]
allData.sort_values(['Coupling','Mode','$m_{med}$','$m_{DM}$','Data-takingperiod'],inplace=True,
              ascending=[False,False,True,True,False],ignore_index=True)

# %%
allData
# Out:
#     Coupling        Mode  $m_{med}$  $m_{DM}$  Data-takingperiod  \
# 0      Axial  DM+QCDjets      100.0       1.0               2018
# 1      Axial  DM+QCDjets      100.0       1.0               2017
# 2      Axial  DM+QCDjets      100.0       1.0               2016
# 3      Axial  DM+QCDjets      100.0      30.0               2018
# 4      Axial  DM+QCDjets      100.0      30.0               2017
# ..       ...         ...        ...       ...                ...
# 199    Axial  DM+QCDjets     2500.0    1000.0               2017
# 200    Axial  DM+QCDjets     2500.0    1000.0               2016
# 201    Axial  DM+QCDjets     2500.0    1500.0               2018
# 202    Axial  DM+QCDjets     2500.0    1500.0               2017
# 203    Axial  DM+QCDjets     2500.0    1500.0               2016
#
#      Luminosity (1/fb)  bin_250.0_280.0  bin_250.0_280.0_ErrorPlus  \
# 0                 59.7    251104.487828               21601.521276
# 1                 41.5    271722.684848               23863.891338
# 2                 36.0    168058.900804               17606.452597
# 3                 59.7    191669.394832               16395.086037
# 4                 41.5    152244.944167               13753.523201
# ..                 ...              ...                        ...
# 199               41.5        15.306873                   1.274373
# 200               36.0        12.548104                   1.120931
# 201               59.7         0.028364                   0.004259
# 202               41.5         0.026579                   0.003746
# 203               36.0         0.014848                   0.003203
#
#      bin_250.0_280.0_ErrorMinus  bin_280.0_310.0  ...  Electronveto  Muonveto  \
# 0                  21601.521276    142777.647570  ...      0.122509  0.122482
# 1                  23863.891338    116392.591297  ...      0.131544  0.131544
# 2                  17606.452597    147370.357757  ...      0.124614  0.124614
# 3                  16395.086037     90514.228525  ...      0.121519  0.121519
# 4                  13753.523201    106533.419009  ...      0.128753  0.128753
# ..                          ...              ...  ...           ...       ...
# 199                    1.274373        10.348824  ...      0.385842  0.385842
# 200                    1.120931         9.717659  ...      0.392637  0.392637
# 201                    0.004259         0.023452  ...      0.383325  0.383325
# 202                    0.003746         0.017602  ...      0.366669  0.366669
# 203                    0.003203         0.015256  ...      0.366204  0.366204
#
#       Tauveto  Bjetveto  Photonveto  $\Delta \phi (jet,p_{T}^{miss})>0.5$ rad  \
# 0    0.119180  0.104340    0.103476                                  0.102896
# 1    0.129459  0.116259    0.115025                                  0.114846
# 2    0.122386  0.108214    0.107884                                  0.107074
# 3    0.118952  0.108331    0.107125                                  0.106105
# 4    0.125361  0.112053    0.111839                                  0.111114
# ..        ...       ...         ...                                       ...
# 199  0.377676  0.334588    0.324343                                  0.322794
# 200  0.382897  0.334718    0.322672                                  0.323224
# 201  0.368547  0.322625    0.311357                                  0.310497
# 202  0.360645  0.313921    0.302280                                  0.302946
# 203  0.355905  0.302667    0.292909                                  0.291798
#
#      LeadingAK4jet$p_{T}>100$GeV  LeadingAK4jet$\eta<2.4$  \
# 0                       0.100214                 0.100214
# 1                       0.112331                 0.112331
# 2                       0.105500                 0.105500
# 3                       0.104741                 0.104741
# 4                       0.109761                 0.109761
# ..                           ...                      ...
# 199                     0.320203                 0.320203
# 200                     0.322659                 0.322659
# 201                     0.308954                 0.308954
# 202                     0.299669                 0.299669
# 203                     0.286696                 0.286696
#
#      HCALmitigation(jets)  HCALmitigation($\phi^{miss}$)
# 0                0.097009                       0.083431
# 1                0.112331                       0.112331
# 2                0.105500                       0.105500
# 3                0.101216                       0.083459
# 4                0.109761                       0.109761
# ..                    ...                            ...
# 199              0.320203                       0.320203
# 200              0.322659                       0.322659
# 201              0.301113                       0.265798
# 202              0.299669                       0.299669
# 203              0.286696                       0.286696
#
# [204 rows x 91 columns]

# %%
allData.to_pickle('../scanResults_axial.pcl')
