# %%
import pandas as pd
import os,glob

# %%
files = [f for f in glob.glob('../DMSimp_axial_0j_match/Events/run*/axial*cms*.pcl')]

# %%
allData = pd.read_pickle(files[0])
for f in files[1:]:
    recastData = pd.read_pickle(f)
    allData = pd.concat((allData,recastData),ignore_index=True)

    
allColumns = allData.columns.tolist()
orderColumns = ['Coupling','Mode','$m_{med}$','$m_{DM}$','Data-takingperiod'] 
orderColumns += [c for c in allColumns if not c in orderColumns]
allData = allData[orderColumns]
allData.sort_values(['Coupling','Mode','$m_{med}$','$m_{DM}$','Data-takingperiod'],inplace=True,
              ascending=[False,False,True,True,False],ignore_index=True)

# %%
allData
# Out:
#     Coupling        Mode  $m_{med}$  $m_{DM}$  Data-takingperiod  \
# 0      Axial  DM+QCDjets      100.0       1.0               2018
# 1      Axial  DM+QCDjets      100.0       1.0               2017
# 2      Axial  DM+QCDjets      100.0       1.0               2016
# 3      Axial  DM+QCDjets      100.0      30.0               2018
# 4      Axial  DM+QCDjets      100.0      30.0               2017
# ..       ...         ...        ...       ...                ...
# 124    Axial  DM+QCDjets     2500.0    1000.0               2017
# 125    Axial  DM+QCDjets     2500.0    1000.0               2016
# 126    Axial  DM+QCDjets     2500.0    1500.0               2018
# 127    Axial  DM+QCDjets     2500.0    1500.0               2017
# 128    Axial  DM+QCDjets     2500.0    1500.0               2016
#
#      Luminosity (1/fb)  bin_250.0_280.0  bin_250.0_280.0_ErrorPlus  \
# 0                 59.7    245267.033817               37712.097224
# 1                 41.5    171037.028539               31648.319020
# 2                 36.0    200355.046482               35688.125801
# 3                 59.7    237337.540589               30585.458654
# 4                 41.5    152203.603754               24589.755037
# ..                 ...              ...                        ...
# 124               41.5        14.232039                   1.241442
# 125               36.0        12.857400                   1.150184
# 126               59.7         0.025180                   0.003968
# 127               41.5         0.025427                   0.003832
# 128               36.0         0.017236                   0.002598
#
#      bin_250.0_280.0_ErrorMinus  bin_280.0_310.0  ...  Electronveto  Muonveto  \
# 0                  37712.097224    167566.730775  ...      0.116956  0.116956
# 1                  31648.319020    144064.647522  ...      0.108655  0.108655
# 2                  35688.125801    158606.033063  ...      0.120576  0.120576
# 3                  30585.458654     87023.598064  ...      0.120255  0.120255
# 4                  24589.755037    101331.647581  ...      0.127466  0.127466
# ..                          ...              ...  ...           ...       ...
# 124                    1.241442        10.003953  ...      0.380096  0.380096
# 125                    1.150184         9.678348  ...      0.378818  0.378818
# 126                    0.003968         0.025579  ...      0.393177  0.393177
# 127                    0.003832         0.011817  ...      0.377999  0.377999
# 128                    0.002598         0.011411  ...      0.377905  0.377905
#
#       Tauveto  Bjetveto  Photonveto  $\Delta \phi (jet,p_{T}^{miss})>0.5$ rad  \
# 0    0.114114  0.107835    0.107032                                  0.107032
# 1    0.108655  0.099589    0.098690                                  0.098690
# 2    0.116778  0.104304    0.103335                                  0.103335
# 3    0.117735  0.106724    0.104588                                  0.104588
# 4    0.125928  0.112970    0.111483                                  0.109671
# ..        ...       ...         ...                                       ...
# 124  0.371021  0.322961    0.310816                                  0.310352
# 125  0.371482  0.324070    0.316453                                  0.316322
# 126  0.384380  0.320049    0.303547                                  0.304565
# 127  0.360850  0.317088    0.307916                                  0.307916
# 128  0.367220  0.319292    0.303053                                  0.303053
#
#      LeadingAK4jet$p_{T}>100$GeV  LeadingAK4jet$\eta<2.4$  \
# 0                       0.105773                 0.105773
# 1                       0.098690                 0.098690
# 2                       0.103335                 0.103335
# 3                       0.104588                 0.103294
# 4                       0.104760                 0.103865
# ..                           ...                      ...
# 124                     0.308471                 0.306797
# 125                     0.311872                 0.311557
# 126                     0.301983                 0.300111
# 127                     0.304112                 0.302716
# 128                     0.299537                 0.298840
#
#      HCALmitigation(jets)  HCALmitigation($\phi^{miss}$)
# 0                0.102218                       0.086625
# 1                0.098690                       0.098690
# 2                0.103335                       0.103335
# 3                0.101075                       0.086948
# 4                0.103865                       0.103865
# ..                    ...                            ...
# 124              0.306797                       0.306797
# 125              0.311557                       0.311557
# 126              0.286656                       0.248021
# 127              0.302716                       0.302716
# 128              0.298840                       0.298840
#
# [129 rows x 91 columns]

# %%
allData.to_pickle('../scanResults.pcl')
