# %%
import pandas as pd

# %%
files = ['../axial_1500_1.pcl', '../axial_1750_1.pcl', '../axial_2000_1.pcl']
allData = pd.read_pickle(files[0])
for f in files[1:]:
    recastData = pd.read_pickle(f)
    allData = pd.concat((allData,recastData),ignore_index=True)

    
allColumns = allData.columns.tolist()
orderColumns = ['Coupling','Mode','$m_{med}$','$m_{DM}$','Data-takingperiod'] 
orderColumns += [c for c in allColumns if not c in orderColumns]
allData = allData[orderColumns]
allData.sort_values(['Coupling','Mode','$m_{med}$','$m_{DM}$','Data-takingperiod'],inplace=True,
              ascending=[False,False,True,True,False],ignore_index=True)

# %%
allData
# Out:
#   Coupling        Mode  $m_{med}$  $m_{DM}$  Data-takingperiod  \
# 0    Axial  DM+QCDjets     1500.0       1.0               2018
# 1    Axial  DM+QCDjets     1500.0       1.0               2017
# 2    Axial  DM+QCDjets     1500.0       1.0               2016
# 3    Axial  DM+QCDjets     1750.0       1.0               2018
# 4    Axial  DM+QCDjets     1750.0       1.0               2017
# 5    Axial  DM+QCDjets     1750.0       1.0               2016
# 6    Axial  DM+QCDjets     2000.0       1.0               2018
# 7    Axial  DM+QCDjets     2000.0       1.0               2017
# 8    Axial  DM+QCDjets     2000.0       1.0               2016
#
#    Luminosity (1/fb)  bin_250.0_280.0  bin_250.0_280.0_ErrorPlus  \
# 0               59.7       702.329838                  38.409060
# 1               41.5       566.387221                  33.501225
# 2               36.0       558.428815                  34.127560
# 3               59.7       392.468875                  23.069178
# 4               41.5       289.727317                  18.770297
# 5               36.0       259.569320                  17.917094
# 6               59.7       154.744635                   9.415424
# 7               41.5       146.250221                  10.758984
# 8               36.0       137.196545                  10.370482
#
#    bin_250.0_280.0_ErrorMinus  bin_280.0_310.0  ...  Electronveto  Muonveto  \
# 0                   38.409060       541.132292  ...      0.384161  0.383910
# 1                   33.501225       503.851812  ...      0.393845  0.393845
# 2                   34.127560       420.663402  ...      0.393155  0.393155
# 3                   23.069178       297.622544  ...      0.398143  0.398032
# 4                   18.770297       262.953360  ...      0.409976  0.409976
# 5                   17.917094       224.165738  ...      0.393560  0.393560
# 6                    9.415424       153.050999  ...      0.388936  0.388936
# 7                   10.758984       120.701936  ...      0.377992  0.377708
# 8                   10.370482       109.592453  ...      0.390888  0.390549
#
#     Tauveto  Bjetveto  Photonveto  $\Delta \phi (jet,p_{T}^{miss})>0.5$ rad  \
# 0  0.374582  0.326757    0.318788                                  0.318257
# 1  0.382359  0.339013    0.328340                                  0.328054
# 2  0.384592  0.341331    0.334650                                  0.334413
# 3  0.388127  0.341684    0.333516                                  0.332704
# 4  0.399420  0.348820    0.338700                                  0.338294
# 5  0.384324  0.340732    0.327463                                  0.327363
# 6  0.380058  0.336623    0.327248                                  0.326841
# 7  0.366852  0.321657    0.315166                                  0.314900
# 8  0.379348  0.333107    0.324076                                  0.323460
#
#    LeadingAK4jet$p_{T}>100$GeV  LeadingAK4jet$\eta<2.4$  HCALmitigation(jets)  \
# 0                     0.314939                 0.313974              0.304742
# 1                     0.326842                 0.326208              0.326208
# 2                     0.331094                 0.329966              0.329966
# 3                     0.329350                 0.328672              0.315988
# 4                     0.336990                 0.335732              0.335732
# 5                     0.325285                 0.323937              0.323937
# 6                     0.325122                 0.324267              0.311418
# 7                     0.312753                 0.311006              0.311006
# 8                     0.321491                 0.319851              0.319851
#
#    HCALmitigation($\phi^{miss}$)
# 0                       0.267150
# 1                       0.326208
# 2                       0.329966
# 3                       0.284404
# 4                       0.335732
# 5                       0.323937
# 6                       0.275559
# 7                       0.311006
# 8                       0.319851
#
# [9 rows x 91 columns]

# %%
allData.to_pickle('../scanResults.pcl')
