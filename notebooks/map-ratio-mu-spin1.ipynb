# %%
import sys,os,glob,copy
sys.path.append('../')
import numpy as np
from statistics import median, mean
from numpy.linalg import norm
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.ticker import AutoMinorLocator

import seaborn as sns
from scipy.interpolate import LinearNDInterpolator,interp2d, griddata
from itertools import product
import matplotlib as mpl
from matplotlib.colors import LogNorm
from IPython.display import display, Markdown
import glob
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

plt.rcParams.update({"savefig.dpi" : 300}) #Figure resolution


#Define plotting style:
sns.set() #Set style
sns.set_style('ticks',{'font.family':'Times New Roman', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
cm = plt.cm.get_cmap('RdYlBu')


pd.set_option('display.max_rows', 200)

# %% [markdown]
# ### Load Recast Data

# %%
# Load models (axial and vector)
# inputFiles = ['../CMS-EXO-20-004/axial_nocut.pcl',
#               '../CMS-EXO-20-004/vector_nocut.pcl']
# inputFiles = ['../CMS-EXO-20-004/axial_comp_add.pcl',
#               '../CMS-EXO-20-004/vector_comp_add.pcl']
inputFiles = ['../CMS-EXO-20-004/AuxInfo/CMS-EXO-20-004-data/DMsimp_spin-1_Monojet_DF.pcl']


dfs = [pd.read_pickle(i) for i in inputFiles]
recastData = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ### Get model points

# %%
models = []
mCols = ['Coupling', 'Mode', '$m_{med}$', '$m_{DM}$']
for row in recastData[mCols].values:
    m = dict(zip(mCols, row.tolist()))
    if m not in models:
        models.append(m)

print('%i models loaded.' %len(models))
# Out:
# 86 models loaded.

# %% [markdown]
# ### Get model parameters

# %%
parameters = {label : list(set([m[label] for m in models])) for label in mCols}
for k,v in parameters.items():
    if len(v) == 1:
        parameters[k] = v[0]
print(parameters)

textstr = '\n'.join([r'%s = %s' %(k,v) for k,v in parameters.items() if k not in ['$m_{med}$','$m_{DM}$']])
print(textstr)
# Out:
# {'Coupling': ['Axial', 'Vector'], 'Mode': 'DM+QCDjets', '$m_{med}$': [1250.0, 100.0, 2500.0, 1000.0, 2250.0, 750.0, 2000.0, 500.0, 1750.0, 250.0, 1500.0], '$m_{DM}$': [1.0, 900.0, 400.0, 150.0, 30.0, 800.0, 40.0, 300.0, 45.0, 1200.0, 55.0, 60.0, 450.0, 70.0, 200.0, 75.0, 1100.0, 600.0, 1500.0, 100.0, 1000.0, 750.0, 1400.0]}
# Coupling = ['Axial', 'Vector']
# Mode = DM+QCDjets

# %% [markdown]
# ### Obtain limit on $\mu$ ratio

# %%
# Select year
recastData = recastData[recastData['Data-takingperiod'] == 2017]

# %%
# label = [c for c in recastData if (c.startswith("HCAL") and not "jets" in c)]

recastData = recastData[['Coupling', '$m_{med}$', '$m_{DM}$', 'Total xsec-pT150 (pb)', '$\mu^{UL}_{obs}$']]

# %%
recastData['$\mu / \sigma$'] = recastData['$\mu^{UL}_{obs}$'] * recastData['Total xsec-pT150 (pb)']
# Out:
# /tmp/ipykernel_335080/1991488404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recastData['$\mu / \sigma$'] = recastData['$\mu^{UL}_{obs}$'] * recastData['Total xsec-pT150 (pb)']

# %%
mCols = ['$m_{med}$','$m_{DM}$']
dataAx = recastData[recastData['Coupling'] == 'Axial']
dataVec = recastData[recastData['Coupling'] == 'Vector']

# %%
keys = list(dataAx[mCols].columns.values)
i1 = dataAx.set_index(keys).index
i2 = dataVec.set_index(keys).index
dataAx = dataAx[i1.isin(i2)]
dataVec = dataVec[i2.isin(i1)]
# i3 = effPseudo.set_index(keys).index
print(len(dataAx),len(dataVec))

masspts = dataVec
masspts = masspts[['$m_{med}$', '$m_{DM}$']]
# Out:
# 43 43

# %%
# Setting the index with mass pairs
dataAx = pd.DataFrame([dataAx.set_index(['$m_{med}$', '$m_{DM}$'])[c] for c in recastData if '$\mu / \sigma$' in c])
dataVec = pd.DataFrame([dataVec.set_index(['$m_{med}$', '$m_{DM}$'])[c] for c in recastData if '$\mu / \sigma$' in c])

# %%
ratio = []
for med, dm in dataAx:
    r = dataVec[med, dm] / dataAx[med, dm]
    ratio.append(r)

# %%
# Plot results
plt.scatter(x=masspts['$m_{med}$'], y=masspts['$m_{DM}$'], vmin=0.75, vmax=1.25,
            cmap=plt.cm.get_cmap('Reds'), c=ratio, s=100)

plt.axline((0, 0), slope=1/2, linestyle='--', color='gray')

cbar=plt.colorbar(label=r'$\frac{(\mu*\sigma)_{axial}}{(\mu*\sigma)_{vector}}$')
plt.xlabel(r'$m_{med}$ (GeV)')
plt.xlim(0,3100)
plt.ylabel(r'$m_{DM}$ (GeV)')
plt.minorticks_on()
# plt.ylim(0,1470)
plt.show()

# %%
ratio
# Out:
# [$\mu / \sigma$    0.978774
#  Name: (100.0, 1.0), dtype: float64,
#  $\mu / \sigma$    1.05056
#  Name: (100.0, 30.0), dtype: float64,
#  $\mu / \sigma$    1.117694
#  Name: (100.0, 40.0), dtype: float64,
#  $\mu / \sigma$    0.930381
#  Name: (100.0, 45.0), dtype: float64,
#  $\mu / \sigma$    3.169581
#  Name: (100.0, 55.0), dtype: float64,
#  $\mu / \sigma$    1.435227
#  Name: (100.0, 60.0), dtype: float64,
#  $\mu / \sigma$    1.321517
#  Name: (100.0, 70.0), dtype: float64,
#  $\mu / \sigma$    1.273763
#  Name: (100.0, 100.0), dtype: float64,
#  $\mu / \sigma$    1.262926
#  Name: (100.0, 150.0), dtype: float64,
#  $\mu / \sigma$    1.381584
#  Name: (100.0, 200.0), dtype: float64,
#  $\mu / \sigma$    1.133752
#  Name: (250.0, 1.0), dtype: float64,
#  $\mu / \sigma$    0.908146
#  Name: (250.0, 75.0), dtype: float64,
#  $\mu / \sigma$    1.046095
#  Name: (250.0, 100.0), dtype: float64,
#  $\mu / \sigma$    1.313928
#  Name: (250.0, 150.0), dtype: float64,
#  $\mu / \sigma$    1.093356
#  Name: (500.0, 1.0), dtype: float64,
#  $\mu / \sigma$    1.056633
#  Name: (500.0, 150.0), dtype: float64,
#  $\mu / \sigma$    1.003716
#  Name: (500.0, 200.0), dtype: float64,
#  $\mu / \sigma$    1.189059
#  Name: (500.0, 300.0), dtype: float64,
#  $\mu / \sigma$    0.978176
#  Name: (750.0, 1.0), dtype: float64,
#  $\mu / \sigma$    1.012392
#  Name: (1000.0, 1.0), dtype: float64,
#  $\mu / \sigma$    1.009496
#  Name: (1000.0, 300.0), dtype: float64,
#  $\mu / \sigma$    1.062046
#  Name: (1000.0, 400.0), dtype: float64,
#  $\mu / \sigma$    1.150834
#  Name: (1000.0, 600.0), dtype: float64,
#  $\mu / \sigma$    1.070784
#  Name: (1250.0, 1.0), dtype: float64,
#  $\mu / \sigma$    1.035389
#  Name: (1500.0, 1.0), dtype: float64,
#  $\mu / \sigma$    1.015482
#  Name: (1500.0, 450.0), dtype: float64,
#  $\mu / \sigma$    1.075404
#  Name: (1500.0, 600.0), dtype: float64,
#  $\mu / \sigma$    1.119652
#  Name: (1500.0, 900.0), dtype: float64,
#  $\mu / \sigma$    1.02711
#  Name: (1750.0, 1.0), dtype: float64,
#  $\mu / \sigma$    0.950336
#  Name: (2000.0, 1.0), dtype: float64,
#  $\mu / \sigma$    1.004471
#  Name: (2000.0, 200.0), dtype: float64,
#  $\mu / \sigma$    1.05019
#  Name: (2000.0, 400.0), dtype: float64,
#  $\mu / \sigma$    1.022977
#  Name: (2000.0, 600.0), dtype: float64,
#  $\mu / \sigma$    0.980361
#  Name: (2000.0, 800.0), dtype: float64,
#  $\mu / \sigma$    0.988079
#  Name: (2000.0, 900.0), dtype: float64,
#  $\mu / \sigma$    1.12961
#  Name: (2000.0, 1100.0), dtype: float64,
#  $\mu / \sigma$    1.098724
#  Name: (2000.0, 1200.0), dtype: float64,
#  $\mu / \sigma$    1.028632
#  Name: (2000.0, 1400.0), dtype: float64,
#  $\mu / \sigma$    1.040683
#  Name: (2250.0, 1.0), dtype: float64,
#  $\mu / \sigma$    0.970183
#  Name: (2500.0, 1.0), dtype: float64,
#  $\mu / \sigma$    0.958601
#  Name: (2500.0, 750.0), dtype: float64,
#  $\mu / \sigma$    1.014964
#  Name: (2500.0, 1000.0), dtype: float64,
#  $\mu / \sigma$    1.069402
#  Name: (2500.0, 1500.0), dtype: float64]

# %%
pts = np.array([x for x in product(np.linspace(0.,3000.,100),np.linspace(0.,1400.,100))])
relDiffPts = griddata(list(zip(masspts['$m_{med}$'],masspts['$m_{DM}$'])),
                  np.array(ratio),pts)

# %%
plt.scatter(x=pts[:,0], y=pts[:,1], vmin=0.5, vmax =1.2, 
            c=relDiffPts, cmap=plt.cm.get_cmap('Reds'))
cbar=plt.colorbar(label=r'$\frac{(\mu*\sigma)_{axial}}{(\mu*\sigma)_{vector}}$')
# plt.axline((1, 1), slope=1/2, linestyle='--', color='gray')

plt.xlabel(r'$m_{med}$ (GeV)')
plt.xlim(0,3100)
plt.ylabel(r'$m_{DM}$ (GeV)')
# plt.ylim(0,1400)
plt.show()
